# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#objects in pandas

# %%
#datafrmae:  combination of series object

# %%
titanic[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(titanic['Name'])  #A Pandas Series is like a column in a table. It is a one-dimensional array holding data of any type.
# Out:
# pandas.core.series.Series

# %%
#getting a particular row in Pandas

# %%
titanic.loc[4]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
#filtering of dataset

# %%
titanic[titanic['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Age']>30
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic[(titanic['Age']>30) & (titanic['Fare']<50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 872          873         0       1
# 873          874         0       3
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    male  35.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Pclass'].isin([1,3])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[(titanic['Age']==30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 79            80         1       3
# 157          158         0       3
# 178          179         0       2
# 213          214         0       2
# 219          220         0       2
# 244          245         0       3
# 253          254         0       3
# 257          258         1       1
# 286          287         1       3
# 308          309         0       2
# 309          310         1       1
# 322          323         1       2
# 365          366         0       3
# 418          419         0       2
# 452          453         0       1
# 488          489         0       3
# 520          521         1       1
# 534          535         0       3
# 537          538         1       1
# 606          607         0       3
# 726          727         1       2
# 747          748         1       2
# 798          799         0       3
# 799          800         0       3
# 842          843         1       1
#
# ...

# %%
titanic[(titanic['Age']!=30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#adding a new column

# %%
titanic['Cost of fare of survived'] = (titanic['Fare']*titanic['Survived'])

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#change column name

# %%
titanic = titanic.rename(columns = {'Fare':'Ticket Fee'})

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#reset_index
filtered_titanic = titanic[titanic['Age']==30].reset_index()
filtered_titanic
# Out:
#     index  PassengerId  Survived  Pclass  \
# 0      79           80         1       3
# 1     157          158         0       3
# 2     178          179         0       2
# 3     213          214         0       2
# 4     219          220         0       2
# 5     244          245         0       3
# 6     253          254         0       3
# 7     257          258         1       1
# 8     286          287         1       3
# 9     308          309         0       2
# 10    309          310         1       1
# 11    322          323         1       2
# 12    365          366         0       3
# 13    418          419         0       2
# 14    452          453         0       1
# 15    488          489         0       3
# 16    520          521         1       1
# 17    534          535         0       3
# 18    537          538         1       1
# 19    606          607         0       3
# 20    726          727         1       2
# 21    747          748         1       2
# ...

# %%
filtered_titanic = titanic[titanic['Age']==30].reset_index(drop=True)
filtered_titanic
# Out:
#     PassengerId  Survived  Pclass  \
# 0            80         1       3
# 1           158         0       3
# 2           179         0       2
# 3           214         0       2
# 4           220         0       2
# 5           245         0       3
# 6           254         0       3
# 7           258         1       1
# 8           287         1       3
# 9           309         0       2
# 10          310         1       1
# 11          323         1       2
# 12          366         0       3
# 13          419         0       2
# 14          453         0       1
# 15          489         0       3
# 16          521         1       1
# 17          535         0       3
# 18          538         1       1
# 19          607         0       3
# 20          727         1       2
# 21          748         1       2
# 22          799         0       3
# 23          800         0       3
# 24          843         1       1
#
# ...

# %%
#sort_values
titanic.sort_values(by='Ticket Fee')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket  Ticket Fee        Cabin Embarked  \
# ...

# %%
#lower
titanic['Name_lowercase'] =titanic['Name'].str.lower()
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Name_lowercase'] =titanic['Name'].str.lower()

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              braund, mr. owen harris    male  22.0      1
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                               heikkinen, miss. laina  female  26.0      0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                             allen, mr. william henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#filtering
titanic[titanic['Name'].str.contains('mrs')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 15            16         1       2
# ..           ...       ...     ...
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 8    johnson, mrs. oscar w (elisabeth vilhelmina berg)  female  27.0      0
# 9                  nasser, mrs. nicholas (adele achem)  female  14.0      1
# 15                    hewlett, mrs. (mary d kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic = pd.read_csv('train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#concat : there are two new people that survived the titanic attack and i want to add them to the list 
data_to_add = {'PassengerId':[892,892], 'Survived':[0,1], 'Pclass':[1,3], 'Name':['Nwoke chibueze','ola joy'], 'Sex':['female','male'], 'Age':[45.0,73.0], 'SibSp':[0,1], 'Parch':[0,0], 'Ticket':[765446,89865], 'Fare':[55,88], 'Cabin':['NaN','NaN'], 'Embarked':['S','E']}
addendum = pd.DataFrame(columns = titanic.columns, data = data_to_add)
addendum
# Out:
#    PassengerId  Survived  Pclass            Name     Sex   Age  SibSp  Parch  \
# 0          892         0       1  Nwoke chibueze  female  45.0      0      0
# 1          892         1       3         ola joy    male  73.0      1      0
#
#    Ticket  Fare Cabin Embarked
# 0  765446    55   NaN        S
# 1   89865    88   NaN        E

# %%
new = pd.concat((titanic,addendum))

# %%
new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
# 0            892         0       1
# 1            892         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new[new['Sex'].str.contains('female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 0            892         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#merge
data_to_add = {'Pclass':[1,2,3], 'Total cabin amount':[371,105,84] }
extra_infor = pd.DataFrame(columns = ['Pclass','Total cabin amount'], data = data_to_add)
extra_infor
# Out:
#    Pclass  Total cabin amount
# 0       1                 371
# 1       2                 105
# 2       3                  84

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.merge(extra_infor, how='left', on='Pclass')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#aggragations

# %%
#describe
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17648\929819788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
#value count
titanic['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
titanic[titanic['Age']==36.5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 148          149         0       2  Navratil, Mr. Michel ("Louis M Hoffman")
#
#       Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 148  male  36.5      0      2  230080  26.0    F2        S

# %%
#groupby

# %%
titanic.groupby('Sex')['Survived'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
titanic.groupby('Sex')['Age'].count()
# Out:
# Sex
# female    261
# male      453
# Name: Age, dtype: int64

# %%
#plotting

# %%
titanic['Age'].plot()
# Out:
# <AxesSubplot:>

# %%
titanic[['Age','Survived']].plot(x='Age',y='Survived', kind='scatter', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
titanic.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
